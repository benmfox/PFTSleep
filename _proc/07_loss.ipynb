# %% [raw]
# ---
# description: I'm lost too.
# output-file: loss.html
# title: Loss functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(huber_loss)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L113){target="_blank" style="float:right; font-size:smaller"}
#
# ### huber_loss
#
# >      huber_loss (preds, target, mask, use_mask=False, padding_mask=None,
# >                  delta=1)
#
# *preds:   [bs x num_patch x n_vars x patch_len]
# targets: [bs x num_patch x n_vars x patch_len]
# mask: [bs x num_patch x n_vars]
# padding_mask: [bs x num_patch]*

# %%
#| echo: false
#| output: asis
show_doc(cosine_similarity_loss)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L95){target="_blank" style="float:right; font-size:smaller"}
#
# ### cosine_similarity_loss
#
# >      cosine_similarity_loss (preds, target, mask, use_mask=False,
# >                              padding_mask=None)
#
# *preds:   [bs x num_patch x n_vars x patch_len]
# targets: [bs x num_patch x n_vars x patch_len]
# mask: [bs x num_patch x n_vars]*

# %%
#| echo: false
#| output: asis
show_doc(cosine_similarity)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L82){target="_blank" style="float:right; font-size:smaller"}
#
# ### cosine_similarity
#
# >      cosine_similarity (preds, target, mask, use_mask=False,
# >                         padding_mask=None)

# %%
#| echo: false
#| output: asis
show_doc(mape)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L75){target="_blank" style="float:right; font-size:smaller"}
#
# ### mape
#
# >      mape (preds, target, mask, use_mask=False)

# %%
#| echo: false
#| output: asis
show_doc(mae)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L72){target="_blank" style="float:right; font-size:smaller"}
#
# ### mae
#
# >      mae (preds, target, mask, use_mask=False, padding_mask=None)

# %%
#| echo: false
#| output: asis
show_doc(rmse)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L69){target="_blank" style="float:right; font-size:smaller"}
#
# ### rmse
#
# >      rmse (preds, target, mask, use_mask=False, padding_mask=None)

# %%
#| echo: false
#| output: asis
show_doc(mse)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L65){target="_blank" style="float:right; font-size:smaller"}
#
# ### mse
#
# >      mse (preds, target, mask, use_mask=False, padding_mask=None)

# %%
#| echo: false
#| output: asis
show_doc(r2_score)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L56){target="_blank" style="float:right; font-size:smaller"}
#
# ### r2_score
#
# >      r2_score (preds, target, mask, use_mask=False)

# %%
#| echo: false
#| output: asis
show_doc(masked_mae_loss)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L35){target="_blank" style="float:right; font-size:smaller"}
#
# ### masked_mae_loss
#
# >      masked_mae_loss (preds, target, mask, use_mask=False, padding_mask=None)
#
# *preds:   [bs x num_patch x n_vars x patch_len]
# targets: [bs x num_patch x n_vars x patch_len]
# mask: [bs x num_patch x n_vars]
# padding_mask: [bs x num_patch]*

# %%
#| echo: false
#| output: asis
show_doc(masked_mse_loss)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L13){target="_blank" style="float:right; font-size:smaller"}
#
# ### masked_mse_loss
#
# >      masked_mse_loss (preds, target, mask, use_mask=False, padding_mask=None)
#
# *preds:   [bs x num_patch x n_vars x patch_len]
# targets: [bs x num_patch x n_vars x patch_len]
# mask: [bs x num_patch x n_vars]
# padding_mask: [bs x num_patch]*

# %%
#| echo: false
#| output: asis
show_doc(patch_continuity_loss)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L134){target="_blank" style="float:right; font-size:smaller"}
#
# ### patch_continuity_loss
#
# >      patch_continuity_loss (preds)
#
# *preds: [bs x num_patch x n_vars x patch_len]
# targets: [bs x num_patch x n_vars x patch_len]*

# %%
x = torch.randn(2,2, 2, 10)

patch_continuity_loss(x)
# Out:
# tensor(0.2936)

# %%
#| echo: false
#| output: asis
show_doc(FocalLoss)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L149){target="_blank" style="float:right; font-size:smaller"}
#
# ### FocalLoss
#
# >      FocalLoss (weight=None, gamma=2.0, reduction='mean', ignore_index=-100)
#
# *adapted from tsai, weighted multiclass focal loss
# https://github.com/timeseriesAI/tsai/blob/bdff96cc8c4c8ea55bc20d7cffd6a72e402f4cb2/tsai/losses.py#L116C1-L140C20*

# %%
criterion = FocalLoss(gamma=0.7, weight=None, ignore_index=0)
batch_size = 10

n_patch = 721
n_class = 5
#m = torch.nn.Softmax(dim=-1)
logits = torch.randn(batch_size, n_class, n_patch)
target = torch.randint(0, n_class, size=(batch_size, n_patch))
criterion(logits, target)
# Out:
# tensor(8.4217)

# %%
#| echo: false
#| output: asis
show_doc(KLDivLoss)
# Out:
# ---
#
# [source](https://github.com/benmfox/PFTSleep/blob/main/pftsleep/loss.py#L196){target="_blank" style="float:right; font-size:smaller"}
#
# ### KLDivLoss
#
# >      KLDivLoss (weight=None, ignore_index=-100)
#
# *Kullback-Leibler Divergence Loss with masking for ignore_index.
# Handles soft labels with ignore_index marked as -100.
#
# Args:
#     logits: [bs x n_classes x pred_labels] - model predictions
#     targets: [bs x n_classes x soft_labels] - soft labels, with ignore_index positions marked as -100
#     or [bs x n_labels] - hard labels*

# %%
x = torch.randn(4,5,10)
y = torch.randint(0,5, size=(4,10))
y_og = y.clone()
y[0,0] = -100

KLDivLoss(ignore_index=-100)(x,y)
# Out:
# tensor(0.4065)
